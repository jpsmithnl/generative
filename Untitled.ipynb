# %%
import drawSvg as draw

d = draw.Drawing(200, 100, origin='center', displayInline=False)
line = draw.Lines(-80, -45,
                    70, -49,
                    95, 49,
                    -90, 40,
                    close=False,
            fill_opacity=0.0,
            stroke='lime')
d.append(line)

# Display in Jupyter notebook
d.rasterize()  # Display as PNG
d  # Display as SVG
# Out:
# <img src="...">

# %%
import drawSvg as draw
import math
import random
random.seed(42)

d = draw.Drawing(400, 400, origin='center', displayInline=False)

def circle(offsets, n_points=40, radius=50):
    points = []
    for i,d in enumerate(list(offsets)+[offsets[0]]):
        theta = i*360./float(n_points)
        x = (radius+d) * math.cos(math.radians(theta))
        y = (radius+d) * math.sin(math.radians(theta))
        points.extend((x,y))
    return points

line_config = dict(
    close=False,
    fill_opacity=0.0,
    stroke='blue'
)

n_points=100
increment=.15
multiplier=1
offsets = list([1]*n_points)
delta = 5
random_changes = list(random.uniform(-delta, delta) for o in offsets)
smoothed = []
window_size = 20
for i in range(len(random_changes)):
    sample = list(random_changes+random_changes[:window_size])[i: i + window_size]
    smoothed.append(sum(sample)/float(len(sample)))
    
for i in range(5,25):
    radius = increment*1.34**i
    offsetsa = list(a+(b*(2**i)*.000002) for a,b in zip(offsets, smoothed))
    d.append( draw.Lines(*circle(offsetsa,n_points,radius), **line_config))
d
# Out:
# <img src="data:image/svg+xml;base64,...">
